# %%
# Handle table-like data and matrices
import numpy as np
import pandas as pd

# Helpers
import sys
from datetime import datetime
from scipy.sparse import csr_matrix,save_npz,load_npz
import pickle
from classifiers import TCRs_selection,TCRs_selection_ttest,t_test

from sklearn.model_selection import cross_val_score,StratifiedKFold
from sklearn.metrics import accuracy_score,roc_auc_score,roc_curve,log_loss
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV,cross_validate
from sklearn.metrics import classification_report
from sklearn.model_selection import LeaveOneOut,KFold,StratifiedKFold
from sklearn.decomposition import PCA,KernelPCA
from scipy.stats import fisher_exact,ttest_ind

from classifiers import MAP_estimator,cal_p_value,TCRs_selection,LOOCV_MAP

# Algorithm
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

data_path = '../data/'

# %%
count_df = pd.read_pickle(data_path+'count_df.pkl')
freq_df = pd.read_pickle(data_path+'freq_df.pkl')
TCRs = count_df.drop(['sample_name','phenotype_status'],axis=1).columns.values
len(TCRs)
# Out:
# 34063

# %%
X = count_df.drop(['sample_name','phenotype_status'],axis=1)
y = count_df['phenotype_status']

# %%
from sklearn.linear_model import LogisticRegression,LogisticRegressionCV

# %%
lrcv = LogisticRegressionCV(penalty='l1',random_state=0,solver='liblinear')

# %%
lrcv.fit(X,y)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None, cv=None, dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='ovr', n_jobs=1, penalty='l1', random_state=0,
#            refit=True, scoring=None, solver='liblinear', tol=0.0001,
#            verbose=0)

# %%
lrcv.C_
# Out:
# array([1291.54966501])

# %%
lr= LogisticRegression(penalty='l1',random_state=0,C=1300)
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = count_df.drop(['sample_name','phenotype_status'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(count_df):
    data = count_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.2)
    print('Length of phenotype_associated TCRs: ',len(asso_TCRs))
    train_cv['sum_asso_TCRs'] = train_cv[asso_TCRs].sum(axis=1)
    test_cv['sum_asso_TCRs'] = test_cv[asso_TCRs].sum(axis=1)
    
    lr.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = lr.predict(test_cv[asso_TCRs])[0]
    test_prob = lr.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 9.496148640311485e-06
#
# HC9
# Length of phenotype_associated TCRs:  31
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999890331742
#
# RA29
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.9437996197183972
#
# RA8
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 1.4134705722194307e-05
#
# RA63
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999451128
#
# RA33
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999843437475
#
# HC17
# Length of phenotype_associated TCRs:  33
# y_true: 0 y_pred: 1 posterior_c1: 0.9961375843270169
#
# HC3
# Length of phenotype_associated TCRs:  33
# y_true: 0 y_pred: 0 posterior_c1: 0.22281788642999736
#
# RA17
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999993891129
#
# RA46
# Length of phenotype_associated TCRs:  61
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999930429
#
# HC6
# Length of phenotype_associated TCRs:  34
# y_true: 0 y_pred: 1 posterior_c1: 0.999999999995314
#
# RA26
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999970560915
#
# RA15
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.9912194036309023
#
# RA53
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999998162661
#
# RA32
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 0 posterior_c1: 0.1292469750261112
#
# RA40
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.14339541743558076
#
# HC8
# Length of phenotype_associated TCRs:  34
# y_true: 0 y_pred: 1 posterior_c1: 1.0
#
# RA51
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 0 posterior_c1: 7.382380656509914e-06
#
# RA68
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 1 posterior_c1: 0.999996151217729
#
# RA21
# Length of phenotype_associated TCRs:  61
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999997304
#
# RA13
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 0 posterior_c1: 0.1734735703121866
#
# RA3
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.9999809022028526
#
# RA41
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 0 posterior_c1: 7.213293348884682e-07
#
# RA9
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 0 posterior_c1: 0.35964716492971055
#
# RA1
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.99922412082723
#
# RA5
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 0 posterior_c1: 0.261450953690845
#
# RA48
# Length of phenotype_associated TCRs:  62
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999959342314
#
# RA6
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.9999984363623464
#
# HC1
# Length of phenotype_associated TCRs:  32
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999929615611
#
# RA23
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 1.4428937134537199e-08
#
# RA54
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 1 posterior_c1: 0.9999888162732417
#
# HC13
# Length of phenotype_associated TCRs:  38
# y_true: 0 y_pred: 1 posterior_c1: 0.9692066507458457
#
# RA49
# Length of phenotype_associated TCRs:  60
# y_true: 1 y_pred: 1 posterior_c1: 0.9999815039394468
#
# RA50
# Length of phenotype_associated TCRs:  60
# y_true: 1 y_pred: 1 posterior_c1: 0.9930942865380595
#
# HC19
# Length of phenotype_associated TCRs:  32
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999998588509
#
# RA56
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 0.2939468217116516
#
# RA22
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999083061448
#
# RA31
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 0 posterior_c1: 8.734319059744896e-05
#
# RA81
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999921843029
#
# RA37
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 0 posterior_c1: 2.1957920552537523e-08
#
# RA52
# Length of phenotype_associated TCRs:  60
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# RA60
# Length of phenotype_associated TCRs:  63
# y_true: 1 y_pred: 0 posterior_c1: 1.3218300419705884e-05
#
# RA28
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.3331930782210654
#
# RA2
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999758749
#
# RA74
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 0 posterior_c1: 0.0013883802576576396
#
# RA10
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 0.3536476408834926
#
# RA4
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999994974855
#
# RA66
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.9961988366042748
#
# RA62
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999996747
#
# RA58
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# HC14
# Length of phenotype_associated TCRs:  32
# y_true: 0 y_pred: 1 posterior_c1: 0.5692349286372074
#
# HC5
# Length of phenotype_associated TCRs:  30
# y_true: 0 y_pred: 0 posterior_c1: 0.2523309004879665
#
# RA16
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999957572614
#
# HC15
# Length of phenotype_associated TCRs:  31
# y_true: 0 y_pred: 0 posterior_c1: 0.25229888244102
#
# HC12
# Length of phenotype_associated TCRs:  36
# y_true: 0 y_pred: 1 posterior_c1: 1.0
#
# RA80
# Length of phenotype_associated TCRs:  61
# y_true: 1 y_pred: 1 posterior_c1: 0.9999998786009429
#
# RA82
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.7385076470144372
#
# RA57
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.9999998559311348
#
# RA72
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 1 posterior_c1: 0.9997874801536856
#
# RA18
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.06198892633457936
#
# HC20
# Length of phenotype_associated TCRs:  33
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999085925216
#
# RA14
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 2.3633613401009943e-06
#
# RA7
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.14339541743558076
#
# RA79
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.5769636487692807
#
# RA25
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 0 posterior_c1: 0.05540420903898114
#
# HC18
# Length of phenotype_associated TCRs:  35
# y_true: 0 y_pred: 1 posterior_c1: 0.9948402708682046
#
# RA59
# Length of phenotype_associated TCRs:  63
# y_true: 1 y_pred: 1 posterior_c1: 0.7055388091683116
#
# RA70
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999922253365
#
# HC7
# Length of phenotype_associated TCRs:  31
# y_true: 0 y_pred: 1 posterior_c1: 0.5660069284212209
#
# RA69
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.1433954174355807
#
# HC10
# Length of phenotype_associated TCRs:  37
# y_true: 0 y_pred: 1 posterior_c1: 1.0
#
# RA12
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.999999984559075
#
# RA11
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 0.06682006891749695
#
# HC4
# Length of phenotype_associated TCRs:  34
# y_true: 0 y_pred: 1 posterior_c1: 0.9999374417546152
#
# RA19
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.9902122592104501
#
# RA30
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 0 posterior_c1: 0.26146723835587926
#
# RA24
# Length of phenotype_associated TCRs:  62
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# HC11
# Length of phenotype_associated TCRs:  40
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999999999873
#
# RA55
# Length of phenotype_associated TCRs:  57
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999999978
#
# RA20
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.9483155368879156
#
# HC2
# Length of phenotype_associated TCRs:  35
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999925043509
#
# RA65
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# RA75
# Length of phenotype_associated TCRs:  58
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# RA76
# Length of phenotype_associated TCRs:  62
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999946319
#
# HC16
# Length of phenotype_associated TCRs:  30
# y_true: 0 y_pred: 0 posterior_c1: 0.25233090048796647
#
# cv auroc: 0.3942307692307692
# cv log_loss: 5.107024306718105

# %%
lr= LogisticRegression(penalty='l1',random_state=0,C=1300)
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = count_df.drop(['sample_name','phenotype_status'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(count_df):
    data = count_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.3)
    print('Length of phenotype_associated TCRs: ',len(asso_TCRs))
    train_cv['sum_asso_TCRs'] = train_cv[asso_TCRs].sum(axis=1)
    test_cv['sum_asso_TCRs'] = test_cv[asso_TCRs].sum(axis=1)
    
    lr.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = lr.predict(test_cv[asso_TCRs])[0]
    test_prob = lr.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# Length of phenotype_associated TCRs:  164
# y_true: 1 y_pred: 0 posterior_c1: 0.0009869857139717165
#
# HC9
# Length of phenotype_associated TCRs:  182
# y_true: 0 y_pred: 1 posterior_c1: 0.9999972333307218
#
# RA29
# Length of phenotype_associated TCRs:  155
# y_true: 1 y_pred: 0 posterior_c1: 0.00555551952086437
#
# RA8
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 0 posterior_c1: 0.007787865850652314
#
# RA63
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 1 posterior_c1: 0.9999389717186408
#
# RA33
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 0 posterior_c1: 1.0794659457856468e-05
#
# HC17
# Length of phenotype_associated TCRs:  193
# y_true: 0 y_pred: 1 posterior_c1: 0.8798309271067021
#
# HC3
# Length of phenotype_associated TCRs:  188
# y_true: 0 y_pred: 1 posterior_c1: 0.9991179593425606
#
# RA17
# Length of phenotype_associated TCRs:  178
# y_true: 1 y_pred: 1 posterior_c1: 0.999999182016522
#
# RA46
# Length of phenotype_associated TCRs:  171
# y_true: 1 y_pred: 1 posterior_c1: 0.9999997494129429
#
# HC6
# Length of phenotype_associated TCRs:  187
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999442132015
#
# RA26
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.955375914726639
#
# RA15
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 1 posterior_c1: 0.9995393064442857
#
# RA53
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 0 posterior_c1: 5.808502748104273e-05
#
# RA32
# Length of phenotype_associated TCRs:  172
# y_true: 1 y_pred: 1 posterior_c1: 0.8285111588485825
#
# RA40
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 0 posterior_c1: 0.14181265203048182
#
# HC8
# Length of phenotype_associated TCRs:  186
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999999998639
#
# RA51
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 0 posterior_c1: 8.128148032706925e-05
#
# RA68
# Length of phenotype_associated TCRs:  171
# y_true: 1 y_pred: 0 posterior_c1: 3.4991793676509568e-06
#
# RA21
# Length of phenotype_associated TCRs:  158
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# RA13
# Length of phenotype_associated TCRs:  172
# y_true: 1 y_pred: 1 posterior_c1: 0.9918181473452442
#
# RA3
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 0 posterior_c1: 0.29890098709434737
#
# RA41
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 0 posterior_c1: 0.0021027163346241714
#
# RA9
# Length of phenotype_associated TCRs:  168
# y_true: 1 y_pred: 1 posterior_c1: 0.994862498693687
#
# RA1
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.9462852136457428
#
# RA5
# Length of phenotype_associated TCRs:  165
# y_true: 1 y_pred: 1 posterior_c1: 0.9626281094982077
#
# RA48
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 1 posterior_c1: 0.9999995654237307
#
# RA6
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 0 posterior_c1: 0.022084639205411587
#
# HC1
# Length of phenotype_associated TCRs:  184
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999968397533
#
# RA23
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 0 posterior_c1: 0.009154532077019157
#
# RA54
# Length of phenotype_associated TCRs:  154
# y_true: 1 y_pred: 1 posterior_c1: 0.9818549692643629
#
# HC13
# Length of phenotype_associated TCRs:  191
# y_true: 0 y_pred: 1 posterior_c1: 0.9950849028678237
#
# RA49
# Length of phenotype_associated TCRs:  149
# y_true: 1 y_pred: 1 posterior_c1: 0.999996083474231
#
# RA50
# Length of phenotype_associated TCRs:  164
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999929807524
#
# HC19
# Length of phenotype_associated TCRs:  185
# y_true: 0 y_pred: 1 posterior_c1: 0.999937482195065
#
# RA56
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 0 posterior_c1: 0.0016331685714575366
#
# RA22
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 1 posterior_c1: 0.9988042694463538
#
# RA31
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 0 posterior_c1: 0.12556957422246698
#
# RA81
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.991811331136487
#
# RA37
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 0 posterior_c1: 1.8322949647770518e-09
#
# RA52
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 1 posterior_c1: 0.9980349494724426
#
# RA60
# Length of phenotype_associated TCRs:  169
# y_true: 1 y_pred: 1 posterior_c1: 0.9844932291863496
#
# RA28
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 0 posterior_c1: 0.00857749511247044
#
# RA2
# Length of phenotype_associated TCRs:  172
# y_true: 1 y_pred: 1 posterior_c1: 0.6626991789291709
#
# RA74
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 0 posterior_c1: 0.4959328817129525
#
# RA10
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 0 posterior_c1: 0.03152104761981017
#
# RA4
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.8475713245763484
#
# RA66
# Length of phenotype_associated TCRs:  168
# y_true: 1 y_pred: 0 posterior_c1: 0.09716517008619543
#
# RA62
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999984506
#
# RA58
# Length of phenotype_associated TCRs:  165
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# HC14
# Length of phenotype_associated TCRs:  190
# y_true: 0 y_pred: 0 posterior_c1: 0.01108501278671458
#
# HC5
# Length of phenotype_associated TCRs:  187
# y_true: 0 y_pred: 0 posterior_c1: 1.610936263245124e-07
#
# RA16
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.9999855465220553
#
# HC15
# Length of phenotype_associated TCRs:  181
# y_true: 0 y_pred: 0 posterior_c1: 0.16543595884196402
#
# HC12
# Length of phenotype_associated TCRs:  202
# y_true: 0 y_pred: 1 posterior_c1: 0.9999993401102778
#
# RA80
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 1 posterior_c1: 0.9999984846809791
#
# RA82
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 0 posterior_c1: 0.0024630171426452538
#
# RA57
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999948860925
#
# RA72
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 0 posterior_c1: 0.03894274960936156
#
# RA18
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 0 posterior_c1: 0.1397422119890902
#
# HC20
# Length of phenotype_associated TCRs:  197
# y_true: 0 y_pred: 1 posterior_c1: 0.9999999099725997
#
# RA14
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 0 posterior_c1: 0.00014701046008120576
#
# RA7
# Length of phenotype_associated TCRs:  178
# y_true: 1 y_pred: 0 posterior_c1: 0.0004851372554691737
#
# RA79
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 1 posterior_c1: 0.9807056430891441
#
# RA25
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 0 posterior_c1: 0.21632972341095835
#
# HC18
# Length of phenotype_associated TCRs:  187
# y_true: 0 y_pred: 1 posterior_c1: 0.9687251364974299
#
# RA59
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 0 posterior_c1: 0.0492573976995496
#
# RA70
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.9989873077383887
#
# HC7
# Length of phenotype_associated TCRs:  185
# y_true: 0 y_pred: 0 posterior_c1: 0.09931143973111452
#
# RA69
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 0 posterior_c1: 0.14159808623657688
#
# HC10
# Length of phenotype_associated TCRs:  204
# y_true: 0 y_pred: 1 posterior_c1: 0.9999867885970477
#
# RA12
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999365457184
#
# RA11
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 0 posterior_c1: 0.3863182219984513
#
# HC4
# Length of phenotype_associated TCRs:  183
# y_true: 0 y_pred: 0 posterior_c1: 0.050314311016269986
#
# RA19
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 1 posterior_c1: 0.8379727407784914
#
# RA30
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 0 posterior_c1: 0.045933063220807105
#
# RA24
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999998032578
#
# HC11
# Length of phenotype_associated TCRs:  210
# y_true: 0 y_pred: 1 posterior_c1: 1.0
#
# RA55
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 1 posterior_c1: 0.9999999999999998
#
# RA20
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 1 posterior_c1: 0.9201412410429413
#
# HC2
# Length of phenotype_associated TCRs:  191
# y_true: 0 y_pred: 0 posterior_c1: 0.17443255781311406
#
# RA65
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 1 posterior_c1: 1.0
#
# RA75
# Length of phenotype_associated TCRs:  164
# y_true: 1 y_pred: 1 posterior_c1: 0.999999997991937
#
# RA76
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 1 posterior_c1: 0.9995455928202254
#
# HC16
# Length of phenotype_associated TCRs:  194
# y_true: 0 y_pred: 1 posterior_c1: 0.9995046576738814
#
# cv auroc: 0.37884615384615394
# cv log_loss: 4.093722751676792

# %%
clf = RandomForestClassifier(bootstrap=True, class_weight= None, criterion='gini',
                                 max_depth=10, max_features='auto', max_leaf_nodes=None,
                                 min_impurity_decrease=0.0, min_impurity_split=None,
                                 min_samples_leaf=1, min_samples_split=2,
                                 min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
                                 oob_score=True, random_state=0, verbose=0, warm_start=False)

# %%
count_df.head()
# Out:
#   sample_name  phenotype_status  \
# 0        RA47                 1
# 1         HC9                 0
# 2        RA29                 1
# 3         RA8                 1
# 4        RA63                 1
#
#    (CAAGGSSYEQYF, TCRBV07, TCRBV07-08, 01, TCRBJ02, TCRBJ02-07, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CACLPGQTSYEQYF, TCRBV30, TCRBV30-01, 01, TCRBJ02, TCRBJ02-07, 01)  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CACRGEGGNTIYF, TCRBV30, TCRBV30-01, 01, TCRBJ01, TCRBJ01-03, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    (CAFGQEGQPQHF, TCRBV30, TCRBV30-01, 01, TCRBJ01, TCRBJ01-05, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CAGETAEAFF, TCRBV06, TCRBV06-01, 01, TCRBJ01, TCRBJ01-01, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CAGGMNTEAFF, TCRBV30, TCRBV30-01, 01, TCRBJ01, TCRBJ01-01, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CAGGNTEAFF, TCRBV02, TCRBV02-01, 01, TCRBJ01, TCRBJ01-01, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CAGGRAGGTDTQYF, TCRBV07, TCRBV07-09, null, TCRBJ02, TCRBJ02-03, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#                                     ...                                    \
# 0                                   ...
# 1                                   ...
# 2                                   ...
# 3                                   ...
# 4                                   ...
#
#    (CSVWTGSSYEQYF, TCRBV29, TCRBV29-01, 01, TCRBJ02, TCRBJ02-07, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CSVYLPGQGNGGYGYTF, TCRBV29, TCRBV29-01, 01, TCRBJ01, TCRBJ01-02, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CSVYMNTEAFF, TCRBV29, TCRBV29-01, 01, TCRBJ01, TCRBJ01-01, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CSVYNNEQFF, TCRBV29, TCRBV29-01, 01, TCRBJ02, TCRBJ02-01, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CSVYRDYEQYF, TCRBV29, TCRBV29-01, 01, TCRBJ02, TCRBJ02-07, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CSVYTGELFF, TCRBV29, TCRBV29-01, 01, TCRBJ02, TCRBJ02-02, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CTGLHETQYF, TCRBV27, TCRBV27-01, 01, TCRBJ02, TCRBJ02-05, 01)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (CVTRDFYEQYF, TCRBV02, TCRBV02-01, 01, TCRBJ02, TCRBJ02-07, 01)  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (RASSPFPTNQAASSNQPQHF, TCRBV07, TCRBV07-03, 03, TCRBJ01, TCRBJ01-05, 01)  \
# 0                                                  0
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    (RASSSTSGGPSWNDEQFF, TCRBV07, TCRBV07-03, 03, TCRBJ02, TCRBJ02-01, 01)
# 0                                                  0
# 1                                                  2
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
# [5 rows x 34065 columns]

# %% [markdown]
# ### No feature selection

# %%
# Init lists
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = count_df.drop(['sample_name','phenotype_status'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(count_df):
    data = count_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs
    
    clf.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test_cv[asso_TCRs])[0]
    test_prob = clf.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# y_true: 1 y_pred: 1 posterior_c1: 0.83
#
# HC9
# y_true: 0 y_pred: 1 posterior_c1: 0.87
#
# RA29
# y_true: 1 y_pred: 1 posterior_c1: 0.8198275862068966
#
# RA8
# y_true: 1 y_pred: 1 posterior_c1: 0.9498275862068966
#
# RA63
# y_true: 1 y_pred: 1 posterior_c1: 0.94
#
# RA33
# y_true: 1 y_pred: 1 posterior_c1: 0.9198412698412699
#
# HC17
# y_true: 0 y_pred: 1 posterior_c1: 0.73
#
# HC3
# y_true: 0 y_pred: 1 posterior_c1: 0.86
#
# RA17
# y_true: 1 y_pred: 1 posterior_c1: 0.969666295884316
#
# RA46
# y_true: 1 y_pred: 1 posterior_c1: 0.8698387096774194
#
# HC6
# y_true: 0 y_pred: 1 posterior_c1: 0.76
#
# RA26
# y_true: 1 y_pred: 1 posterior_c1: 0.85
#
# RA15
# y_true: 1 y_pred: 1 posterior_c1: 0.91
#
# RA53
# y_true: 1 y_pred: 1 posterior_c1: 0.8596606269772792
#
# RA32
# y_true: 1 y_pred: 1 posterior_c1: 0.8898245614035087
#
# RA40
# y_true: 1 y_pred: 1 posterior_c1: 0.9498360655737704
#
# HC8
# y_true: 0 y_pred: 1 posterior_c1: 0.88
#
# RA51
# y_true: 1 y_pred: 1 posterior_c1: 0.84
#
# RA68
# y_true: 1 y_pred: 1 posterior_c1: 0.8398214285714286
#
# RA21
# y_true: 1 y_pred: 1 posterior_c1: 0.7398214285714286
#
# RA13
# y_true: 1 y_pred: 1 posterior_c1: 0.9798387096774194
#
# RA3
# y_true: 1 y_pred: 1 posterior_c1: 0.95
#
# RA41
# y_true: 1 y_pred: 1 posterior_c1: 0.95
#
# RA9
# y_true: 1 y_pred: 1 posterior_c1: 0.86
#
# RA1
# y_true: 1 y_pred: 1 posterior_c1: 0.96
#
# RA5
# y_true: 1 y_pred: 1 posterior_c1: 0.92
#
# RA48
# y_true: 1 y_pred: 1 posterior_c1: 0.77
#
# RA6
# y_true: 1 y_pred: 1 posterior_c1: 0.89
#
# HC1
# y_true: 0 y_pred: 1 posterior_c1: 0.85
#
# RA23
# y_true: 1 y_pred: 1 posterior_c1: 0.92
#
# RA54
# y_true: 1 y_pred: 1 posterior_c1: 0.85
#
# HC13
# y_true: 0 y_pred: 1 posterior_c1: 0.83
#
# RA49
# y_true: 1 y_pred: 1 posterior_c1: 0.63
#
# RA50
# y_true: 1 y_pred: 1 posterior_c1: 0.7996688560481664
#
# HC19
# y_true: 0 y_pred: 1 posterior_c1: 0.95
#
# RA56
# y_true: 1 y_pred: 1 posterior_c1: 0.7598181818181818
#
# RA22
# y_true: 1 y_pred: 1 posterior_c1: 0.8898181818181818
#
# RA31
# y_true: 1 y_pred: 1 posterior_c1: 0.9598245614035088
#
# RA81
# y_true: 1 y_pred: 1 posterior_c1: 0.9098412698412699
#
# RA37
# y_true: 1 y_pred: 1 posterior_c1: 0.95
#
# RA52
# y_true: 1 y_pred: 1 posterior_c1: 0.78984375
#
# RA60
# y_true: 1 y_pred: 1 posterior_c1: 0.8198484848484848
#
# RA28
# y_true: 1 y_pred: 1 posterior_c1: 0.9196610169491527
#
# RA2
# y_true: 1 y_pred: 1 posterior_c1: 0.91
#
# RA74
# y_true: 1 y_pred: 1 posterior_c1: 0.7898333333333334
#
# RA10
# y_true: 1 y_pred: 1 posterior_c1: 0.9596515151515151
#
# RA4
# y_true: 1 y_pred: 1 posterior_c1: 0.8696515151515152
#
# RA66
# y_true: 1 y_pred: 1 posterior_c1: 0.86
#
# RA62
# y_true: 1 y_pred: 1 posterior_c1: 0.9393166937229437
#
# RA58
# y_true: 1 y_pred: 1 posterior_c1: 0.8194960317460317
#
# HC14
# y_true: 0 y_pred: 1 posterior_c1: 0.8498214285714286
#
# HC5
# y_true: 0 y_pred: 1 posterior_c1: 0.9198360655737704
#
# RA16
# y_true: 1 y_pred: 1 posterior_c1: 0.9596773354150403
#
# HC15
# y_true: 0 y_pred: 1 posterior_c1: 0.87
#
# HC12
# y_true: 0 y_pred: 1 posterior_c1: 0.7896825396825398
#
# RA80
# y_true: 1 y_pred: 1 posterior_c1: 0.84
#
# RA82
# y_true: 1 y_pred: 1 posterior_c1: 0.8079999999999999
#
# RA57
# y_true: 1 y_pred: 1 posterior_c1: 0.8
#
# RA72
# y_true: 1 y_pred: 1 posterior_c1: 0.8798148148148148
#
# RA18
# y_true: 1 y_pred: 1 posterior_c1: 0.9898148148148148
#
# HC20
# y_true: 0 y_pred: 1 posterior_c1: 0.7196363636363636
#
# RA14
# y_true: 1 y_pred: 1 posterior_c1: 0.9698360655737704
#
# RA7
# y_true: 1 y_pred: 1 posterior_c1: 0.98
#
# RA79
# y_true: 1 y_pred: 1 posterior_c1: 0.9798113207547169
#
# RA25
# y_true: 1 y_pred: 1 posterior_c1: 0.8
#
# HC18
# y_true: 0 y_pred: 1 posterior_c1: 0.82984375
#
# RA59
# y_true: 1 y_pred: 1 posterior_c1: 0.75984375
#
# RA70
# y_true: 1 y_pred: 1 posterior_c1: 0.94
#
# HC7
# y_true: 0 y_pred: 1 posterior_c1: 0.8
#
# RA69
# y_true: 1 y_pred: 1 posterior_c1: 0.9898039215686274
#
# HC10
# y_true: 0 y_pred: 1 posterior_c1: 0.65
#
# RA12
# y_true: 1 y_pred: 1 posterior_c1: 0.95
#
# RA11
# y_true: 1 y_pred: 1 posterior_c1: 0.87
#
# HC4
# y_true: 0 y_pred: 1 posterior_c1: 0.8166666666666668
#
# RA19
# y_true: 1 y_pred: 1 posterior_c1: 0.9898076923076923
#
# RA30
# y_true: 1 y_pred: 1 posterior_c1: 0.94
#
# RA24
# y_true: 1 y_pred: 1 posterior_c1: 0.82
#
# HC11
# y_true: 0 y_pred: 1 posterior_c1: 0.69
#
# RA55
# y_true: 1 y_pred: 1 posterior_c1: 0.6675
#
# RA20
# y_true: 1 y_pred: 1 posterior_c1: 0.93
#
# HC2
# y_true: 0 y_pred: 1 posterior_c1: 0.79
#
# RA65
# y_true: 1 y_pred: 1 posterior_c1: 0.8998360655737705
#
# RA75
# y_true: 1 y_pred: 1 posterior_c1: 0.7898113207547169
#
# RA76
# y_true: 1 y_pred: 1 posterior_c1: 0.73
#
# HC16
# y_true: 0 y_pred: 1 posterior_c1: 0.84
#
# cv auroc: 0.7192307692307693
# cv log_loss: 0.520484247614149

# %% [markdown]
# #### Feature selection based on Fisher exact test

# %%
# Init lists
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = count_df.drop(['sample_name','phenotype_status'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(count_df):
    data = count_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.3)
    print('Length of phenotype_associated TCRs: ',len(asso_TCRs))
    train_cv['sum_asso_TCRs'] = train_cv[asso_TCRs].sum(axis=1)
    test_cv['sum_asso_TCRs'] = test_cv[asso_TCRs].sum(axis=1)
    
    clf.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test_cv[asso_TCRs])[0]
    test_prob = clf.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# Length of phenotype_associated TCRs:  164
# y_true: 1 y_pred: 1 posterior_c1: 0.6203822171832128
#
# HC9
# Length of phenotype_associated TCRs:  182
# y_true: 0 y_pred: 1 posterior_c1: 0.5965568031800779
#
# RA29
# Length of phenotype_associated TCRs:  155
# y_true: 1 y_pred: 1 posterior_c1: 0.6326772699041977
#
# RA8
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 0 posterior_c1: 0.37218024006453176
#
# RA63
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 1 posterior_c1: 0.5660014632161906
#
# RA33
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.6928672522670203
#
# HC17
# Length of phenotype_associated TCRs:  193
# y_true: 0 y_pred: 1 posterior_c1: 0.6632388801734455
#
# HC3
# Length of phenotype_associated TCRs:  188
# y_true: 0 y_pred: 1 posterior_c1: 0.6893378921003861
#
# RA17
# Length of phenotype_associated TCRs:  178
# y_true: 1 y_pred: 1 posterior_c1: 0.5870056076010293
#
# RA46
# Length of phenotype_associated TCRs:  171
# y_true: 1 y_pred: 1 posterior_c1: 0.7361938544810276
#
# HC6
# Length of phenotype_associated TCRs:  187
# y_true: 0 y_pred: 1 posterior_c1: 0.7252628428274118
#
# RA26
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.6369254897101984
#
# RA15
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 1 posterior_c1: 0.7351540127203733
#
# RA53
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 1 posterior_c1: 0.709025408415762
#
# RA32
# Length of phenotype_associated TCRs:  172
# y_true: 1 y_pred: 0 posterior_c1: 0.47454008427347716
#
# RA40
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 0 posterior_c1: 0.3245725981638535
#
# HC8
# Length of phenotype_associated TCRs:  186
# y_true: 0 y_pred: 1 posterior_c1: 0.6816971331509153
#
# RA51
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 1 posterior_c1: 0.6700433056905376
#
# RA68
# Length of phenotype_associated TCRs:  171
# y_true: 1 y_pred: 1 posterior_c1: 0.6494580507250773
#
# RA21
# Length of phenotype_associated TCRs:  158
# y_true: 1 y_pred: 1 posterior_c1: 0.8374310684908467
#
# RA13
# Length of phenotype_associated TCRs:  172
# y_true: 1 y_pred: 1 posterior_c1: 0.5808682443243336
#
# RA3
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 1 posterior_c1: 0.506842213047029
#
# RA41
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.598349193727518
#
# RA9
# Length of phenotype_associated TCRs:  168
# y_true: 1 y_pred: 1 posterior_c1: 0.6434954869024712
#
# RA1
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.5224240337667453
#
# RA5
# Length of phenotype_associated TCRs:  165
# y_true: 1 y_pred: 1 posterior_c1: 0.6159006214137653
#
# RA48
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 1 posterior_c1: 0.7143633451987665
#
# RA6
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 1 posterior_c1: 0.5373382014264084
#
# HC1
# Length of phenotype_associated TCRs:  184
# y_true: 0 y_pred: 1 posterior_c1: 0.6884059221812748
#
# RA23
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.5514132043256079
#
# RA54
# Length of phenotype_associated TCRs:  154
# y_true: 1 y_pred: 1 posterior_c1: 0.7996659707280304
#
# HC13
# Length of phenotype_associated TCRs:  191
# y_true: 0 y_pred: 1 posterior_c1: 0.7426529095253865
#
# RA49
# Length of phenotype_associated TCRs:  149
# y_true: 1 y_pred: 1 posterior_c1: 0.8837220654824105
#
# RA50
# Length of phenotype_associated TCRs:  164
# y_true: 1 y_pred: 1 posterior_c1: 0.7459262645521599
#
# HC19
# Length of phenotype_associated TCRs:  185
# y_true: 0 y_pred: 1 posterior_c1: 0.7411126702196935
#
# RA56
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 0 posterior_c1: 0.4661648337981736
#
# RA22
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 1 posterior_c1: 0.5954822597256443
#
# RA31
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.6386808008581358
#
# RA81
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.592119805718962
#
# RA37
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 0 posterior_c1: 0.4482261671193777
#
# RA52
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 1 posterior_c1: 0.8321798594928026
#
# RA60
# Length of phenotype_associated TCRs:  169
# y_true: 1 y_pred: 1 posterior_c1: 0.6261339216284899
#
# RA28
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.5654377958654995
#
# RA2
# Length of phenotype_associated TCRs:  172
# y_true: 1 y_pred: 0 posterior_c1: 0.4354732869824832
#
# RA74
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 1 posterior_c1: 0.7492425500325866
#
# RA10
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 0 posterior_c1: 0.4161771958902861
#
# RA4
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.6334196574805523
#
# RA66
# Length of phenotype_associated TCRs:  168
# y_true: 1 y_pred: 0 posterior_c1: 0.4647313695159581
#
# RA62
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.6622830120113723
#
# RA58
# Length of phenotype_associated TCRs:  165
# y_true: 1 y_pred: 1 posterior_c1: 0.6090529077346303
#
# HC14
# Length of phenotype_associated TCRs:  190
# y_true: 0 y_pred: 1 posterior_c1: 0.5989624332593817
#
# HC5
# Length of phenotype_associated TCRs:  187
# y_true: 0 y_pred: 1 posterior_c1: 0.6466993937817789
#
# RA16
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 1 posterior_c1: 0.513521965576602
#
# HC15
# Length of phenotype_associated TCRs:  181
# y_true: 0 y_pred: 0 posterior_c1: 0.4630123023560619
#
# HC12
# Length of phenotype_associated TCRs:  202
# y_true: 0 y_pred: 1 posterior_c1: 0.8526001445114575
#
# RA80
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 1 posterior_c1: 0.7885923899513795
#
# RA82
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 1 posterior_c1: 0.6831102257025762
#
# RA57
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 1 posterior_c1: 0.5638360358290384
#
# RA72
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.6254554499100543
#
# RA18
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 0 posterior_c1: 0.38278971725793015
#
# HC20
# Length of phenotype_associated TCRs:  197
# y_true: 0 y_pred: 1 posterior_c1: 0.8930159453525575
#
# RA14
# Length of phenotype_associated TCRs:  176
# y_true: 1 y_pred: 0 posterior_c1: 0.3588144438236088
#
# RA7
# Length of phenotype_associated TCRs:  178
# y_true: 1 y_pred: 0 posterior_c1: 0.339404462993698
#
# RA79
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 0 posterior_c1: 0.4636360524683131
#
# RA25
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 1 posterior_c1: 0.595067051027878
#
# HC18
# Length of phenotype_associated TCRs:  187
# y_true: 0 y_pred: 1 posterior_c1: 0.6757966153738468
#
# RA59
# Length of phenotype_associated TCRs:  162
# y_true: 1 y_pred: 1 posterior_c1: 0.6904105559763845
#
# RA70
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 1 posterior_c1: 0.6076632538807653
#
# HC7
# Length of phenotype_associated TCRs:  185
# y_true: 0 y_pred: 1 posterior_c1: 0.5754697309066171
#
# RA69
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 0 posterior_c1: 0.3344787564270081
#
# HC10
# Length of phenotype_associated TCRs:  204
# y_true: 0 y_pred: 1 posterior_c1: 0.8180476060415599
#
# RA12
# Length of phenotype_associated TCRs:  175
# y_true: 1 y_pred: 1 posterior_c1: 0.6282029367993165
#
# RA11
# Length of phenotype_associated TCRs:  170
# y_true: 1 y_pred: 0 posterior_c1: 0.4393371250679504
#
# HC4
# Length of phenotype_associated TCRs:  183
# y_true: 0 y_pred: 1 posterior_c1: 0.6440269627908591
#
# RA19
# Length of phenotype_associated TCRs:  174
# y_true: 1 y_pred: 0 posterior_c1: 0.4751816546638612
#
# RA30
# Length of phenotype_associated TCRs:  173
# y_true: 1 y_pred: 0 posterior_c1: 0.4973979543297356
#
# RA24
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 1 posterior_c1: 0.7411657624744111
#
# HC11
# Length of phenotype_associated TCRs:  210
# y_true: 0 y_pred: 1 posterior_c1: 0.9198052357727552
#
# RA55
# Length of phenotype_associated TCRs:  163
# y_true: 1 y_pred: 1 posterior_c1: 0.8075748938490086
#
# RA20
# Length of phenotype_associated TCRs:  177
# y_true: 1 y_pred: 1 posterior_c1: 0.537164660574921
#
# HC2
# Length of phenotype_associated TCRs:  191
# y_true: 0 y_pred: 1 posterior_c1: 0.8188184258429949
#
# RA65
# Length of phenotype_associated TCRs:  166
# y_true: 1 y_pred: 1 posterior_c1: 0.766128104501644
#
# RA75
# Length of phenotype_associated TCRs:  164
# y_true: 1 y_pred: 1 posterior_c1: 0.8735554756690185
#
# RA76
# Length of phenotype_associated TCRs:  167
# y_true: 1 y_pred: 1 posterior_c1: 0.7731888440280231
#
# HC16
# Length of phenotype_associated TCRs:  194
# y_true: 0 y_pred: 1 posterior_c1: 0.7091214242256187
#
# cv auroc: 0.27999999999999997
# cv log_loss: 0.7193908815257406

# %%
# Init lists
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = count_df.drop(['sample_name','phenotype_status'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(count_df):
    data = count_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.2)
    print('Length of phenotype_associated TCRs: ',len(asso_TCRs))
    train_cv['sum_asso_TCRs'] = train_cv[asso_TCRs].sum(axis=1)
    test_cv['sum_asso_TCRs'] = test_cv[asso_TCRs].sum(axis=1)
    
    clf.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test_cv[asso_TCRs])[0]
    test_prob = clf.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.5666676136940176
#
# HC9
# Length of phenotype_associated TCRs:  31
# y_true: 0 y_pred: 1 posterior_c1: 0.6461407870649709
#
# RA29
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.5654590646851942
#
# RA8
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 0.30810029548018153
#
# RA63
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.6463414891313686
#
# RA33
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.7607860457171353
#
# HC17
# Length of phenotype_associated TCRs:  33
# y_true: 0 y_pred: 1 posterior_c1: 0.6262651458634906
#
# HC3
# Length of phenotype_associated TCRs:  33
# y_true: 0 y_pred: 1 posterior_c1: 0.7050244675398258
#
# RA17
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.6269031753160018
#
# RA46
# Length of phenotype_associated TCRs:  61
# y_true: 1 y_pred: 1 posterior_c1: 0.7251669742537656
#
# HC6
# Length of phenotype_associated TCRs:  34
# y_true: 0 y_pred: 1 posterior_c1: 0.8189889749025718
#
# RA26
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.7273259178079451
#
# RA15
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.6499286177794841
#
# RA53
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.7673389767818014
#
# RA32
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 0 posterior_c1: 0.4160077905209702
#
# RA40
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.3020131400527801
#
# HC8
# Length of phenotype_associated TCRs:  34
# y_true: 0 y_pred: 1 posterior_c1: 0.7614920251183651
#
# RA51
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.7430011343980047
#
# RA68
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 1 posterior_c1: 0.7078348962665554
#
# RA21
# Length of phenotype_associated TCRs:  61
# y_true: 1 y_pred: 1 posterior_c1: 0.8574270172377964
#
# RA13
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.6408527242611244
#
# RA3
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.6033949336785172
#
# RA41
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.5731024877682269
#
# RA9
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.6294676949186663
#
# RA1
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.5532662783803574
#
# RA5
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.6178502840419667
#
# RA48
# Length of phenotype_associated TCRs:  62
# y_true: 1 y_pred: 1 posterior_c1: 0.7771428711364529
#
# RA6
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.550581797905545
#
# HC1
# Length of phenotype_associated TCRs:  32
# y_true: 0 y_pred: 1 posterior_c1: 0.7745232983303567
#
# RA23
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.6394030329574513
#
# RA54
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 1 posterior_c1: 0.7476948671686343
#
# HC13
# Length of phenotype_associated TCRs:  38
# y_true: 0 y_pred: 1 posterior_c1: 0.8615031425182376
#
# RA49
# Length of phenotype_associated TCRs:  60
# y_true: 1 y_pred: 1 posterior_c1: 0.948410138248848
#
# RA50
# Length of phenotype_associated TCRs:  60
# y_true: 1 y_pred: 1 posterior_c1: 0.721426089353174
#
# HC19
# Length of phenotype_associated TCRs:  32
# y_true: 0 y_pred: 1 posterior_c1: 0.8992325836514659
#
# RA56
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.5229988552632603
#
# RA22
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.6275455713454401
#
# RA31
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.6994593898656882
#
# RA81
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.7726167831351887
#
# RA37
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.5348648923866164
#
# RA52
# Length of phenotype_associated TCRs:  60
# y_true: 1 y_pred: 1 posterior_c1: 0.8757000448028674
#
# RA60
# Length of phenotype_associated TCRs:  63
# y_true: 1 y_pred: 1 posterior_c1: 0.7167974500238985
#
# RA28
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.664544111602644
#
# RA2
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.35948780762830634
#
# RA74
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.77746767450464
#
# RA10
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 0 posterior_c1: 0.48084759978515124
#
# RA4
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.784978484040421
#
# RA66
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.6038567367867563
#
# RA62
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.7969808755729416
#
# RA58
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.6938449331972669
#
# HC14
# Length of phenotype_associated TCRs:  32
# y_true: 0 y_pred: 0 posterior_c1: 0.487437656884212
#
# HC5
# Length of phenotype_associated TCRs:  30
# y_true: 0 y_pred: 0 posterior_c1: 0.34936913452303064
#
# RA16
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.6472899446117496
#
# HC15
# Length of phenotype_associated TCRs:  31
# y_true: 0 y_pred: 1 posterior_c1: 0.5615979304173714
#
# HC12
# Length of phenotype_associated TCRs:  36
# y_true: 0 y_pred: 1 posterior_c1: 0.9577148294539597
#
# RA80
# Length of phenotype_associated TCRs:  61
# y_true: 1 y_pred: 1 posterior_c1: 0.7410108919610221
#
# RA82
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.6446000086491439
#
# RA57
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.7292303221147738
#
# RA72
# Length of phenotype_associated TCRs:  64
# y_true: 1 y_pred: 1 posterior_c1: 0.6334791512156212
#
# RA18
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.4748161166948152
#
# HC20
# Length of phenotype_associated TCRs:  33
# y_true: 0 y_pred: 1 posterior_c1: 0.9800482625482626
#
# RA14
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.38220763815118725
#
# RA7
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.2917449674196545
#
# RA79
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 0 posterior_c1: 0.38361509623652745
#
# RA25
# Length of phenotype_associated TCRs:  65
# y_true: 1 y_pred: 1 posterior_c1: 0.6277690661948434
#
# HC18
# Length of phenotype_associated TCRs:  35
# y_true: 0 y_pred: 1 posterior_c1: 0.8069199205834728
#
# RA59
# Length of phenotype_associated TCRs:  63
# y_true: 1 y_pred: 1 posterior_c1: 0.8238845000425106
#
# RA70
# Length of phenotype_associated TCRs:  67
# y_true: 1 y_pred: 1 posterior_c1: 0.7134176457902949
#
# HC7
# Length of phenotype_associated TCRs:  31
# y_true: 0 y_pred: 0 posterior_c1: 0.4927875401892316
#
# RA69
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 0 posterior_c1: 0.30958060762072426
#
# HC10
# Length of phenotype_associated TCRs:  37
# y_true: 0 y_pred: 1 posterior_c1: 0.8931562299658253
#
# RA12
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.6929576550412855
#
# RA11
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.5167638075318653
#
# HC4
# Length of phenotype_associated TCRs:  34
# y_true: 0 y_pred: 1 posterior_c1: 0.9005646724795328
#
# RA19
# Length of phenotype_associated TCRs:  69
# y_true: 1 y_pred: 1 posterior_c1: 0.5224730585542822
#
# RA30
# Length of phenotype_associated TCRs:  68
# y_true: 1 y_pred: 1 posterior_c1: 0.6083336461390132
#
# RA24
# Length of phenotype_associated TCRs:  62
# y_true: 1 y_pred: 1 posterior_c1: 0.7513647094384633
#
# HC11
# Length of phenotype_associated TCRs:  40
# y_true: 0 y_pred: 1 posterior_c1: 0.9462152777777777
#
# RA55
# Length of phenotype_associated TCRs:  57
# y_true: 1 y_pred: 1 posterior_c1: 0.8642938964021866
#
# RA20
# Length of phenotype_associated TCRs:  70
# y_true: 1 y_pred: 1 posterior_c1: 0.5266184749001162
#
# HC2
# Length of phenotype_associated TCRs:  35
# y_true: 0 y_pred: 1 posterior_c1: 0.8845805705527826
#
# RA65
# Length of phenotype_associated TCRs:  66
# y_true: 1 y_pred: 1 posterior_c1: 0.8615997168776478
#
# RA75
# Length of phenotype_associated TCRs:  58
# y_true: 1 y_pred: 1 posterior_c1: 0.9044951714951714
#
# RA76
# Length of phenotype_associated TCRs:  62
# y_true: 1 y_pred: 1 posterior_c1: 0.7899134870370971
#
# HC16
# Length of phenotype_associated TCRs:  30
# y_true: 0 y_pred: 0 posterior_c1: 0.36891062644976147
#
# cv auroc: 0.33307692307692305
# cv log_loss: 0.7598337086303928

# %% [markdown]
# ## Feature selection: Intersection of Fisher and ttest

# %%
# Init lists
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = freq_df.drop(['sample_name','phenotype_status'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(freq_df):
    train_cv, test_cv = freq_df.iloc[train_index], freq_df.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs1 = TCRs_selection(train_cv,TCRs,0.2)
    asso_TCRs2 = TCRs_selection_ttest(train_cv,TCRs,{'threshold':0.02})
    print('Length of phenotype_associated TCRs: ','Fisher:',len(asso_TCRs1),'t-test:',len(asso_TCRs2))

    asso_TCRs = list(set(asso_TCRs1).intersection(set(asso_TCRs2)))
    print('Length of the intersection:',len(asso_TCRs))

    clf.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test_cv[asso_TCRs])[0]
    test_prob = clf.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 85
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.5081539649835483
#
# HC9
# Length of phenotype_associated TCRs:  Fisher: 31 t-test: 93
# Length of the intersection: 25
# y_true: 0 y_pred: 1 posterior_c1: 0.6403034736640675
#
# RA29
# Length of phenotype_associated TCRs:  Fisher: 65 t-test: 83
# Length of the intersection: 46
# y_true: 1 y_pred: 0 posterior_c1: 0.44841686970974853
#
# RA8
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 92
# Length of the intersection: 50
# y_true: 1 y_pred: 1 posterior_c1: 0.5649911472914405
#
# RA63
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 92
# Length of the intersection: 50
# y_true: 1 y_pred: 1 posterior_c1: 0.7889682443077872
#
# RA33
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 89
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.951547619047619
#
# HC17
# Length of phenotype_associated TCRs:  Fisher: 33 t-test: 98
# Length of the intersection: 27
# y_true: 0 y_pred: 1 posterior_c1: 0.5625910652254994
#
# HC3
# Length of phenotype_associated TCRs:  Fisher: 33 t-test: 95
# Length of the intersection: 26
# y_true: 0 y_pred: 1 posterior_c1: 0.7163749137043203
#
# RA17
# Length of phenotype_associated TCRs:  Fisher: 70 t-test: 95
# Length of the intersection: 52
# y_true: 1 y_pred: 1 posterior_c1: 0.7484739275193948
#
# RA46
# Length of phenotype_associated TCRs:  Fisher: 61 t-test: 83
# Length of the intersection: 41
# y_true: 1 y_pred: 1 posterior_c1: 0.6658516796656777
#
# HC6
# Length of phenotype_associated TCRs:  Fisher: 34 t-test: 97
# Length of the intersection: 27
# y_true: 0 y_pred: 1 posterior_c1: 0.8465794642847887
#
# RA26
# Length of phenotype_associated TCRs:  Fisher: 68 t-test: 92
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.7218429549408814
#
# RA15
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 85
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.8476662268004708
#
# RA53
# Length of phenotype_associated TCRs:  Fisher: 65 t-test: 84
# Length of the intersection: 45
# y_true: 1 y_pred: 1 posterior_c1: 0.8510526017461503
#
# RA32
# Length of phenotype_associated TCRs:  Fisher: 64 t-test: 86
# Length of the intersection: 47
# y_true: 1 y_pred: 1 posterior_c1: 0.6611390273491236
#
# RA40
# Length of phenotype_associated TCRs:  Fisher: 70 t-test: 93
# Length of the intersection: 50
# y_true: 1 y_pred: 0 posterior_c1: 0.3343263764461637
#
# HC8
# Length of phenotype_associated TCRs:  Fisher: 34 t-test: 96
# Length of the intersection: 27
# y_true: 0 y_pred: 1 posterior_c1: 0.9057095882232145
#
# RA51
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 84
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.9271149438796498
#
# RA68
# Length of phenotype_associated TCRs:  Fisher: 64 t-test: 90
# Length of the intersection: 47
# y_true: 1 y_pred: 1 posterior_c1: 0.80651395066736
#
# RA21
# Length of phenotype_associated TCRs:  Fisher: 61 t-test: 80
# Length of the intersection: 44
# y_true: 1 y_pred: 1 posterior_c1: 0.5453377717823401
#
# RA13
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 93
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.7090610289671028
#
# RA3
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 93
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.7904773193020443
#
# RA41
# Length of phenotype_associated TCRs:  Fisher: 66 t-test: 90
# Length of the intersection: 46
# y_true: 1 y_pred: 1 posterior_c1: 0.9616860465116279
#
# RA9
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 88
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.7533276688218099
#
# RA1
# Length of phenotype_associated TCRs:  Fisher: 68 t-test: 94
# Length of the intersection: 50
# y_true: 1 y_pred: 1 posterior_c1: 0.8923356607133992
#
# RA5
# Length of phenotype_associated TCRs:  Fisher: 66 t-test: 86
# Length of the intersection: 45
# y_true: 1 y_pred: 0 posterior_c1: 0.4729083625532226
#
# RA48
# Length of phenotype_associated TCRs:  Fisher: 62 t-test: 81
# Length of the intersection: 44
# y_true: 1 y_pred: 1 posterior_c1: 0.7932719880344105
#
# RA6
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 91
# Length of the intersection: 47
# y_true: 1 y_pred: 1 posterior_c1: 0.6891663910315324
#
# HC1
# Length of phenotype_associated TCRs:  Fisher: 32 t-test: 95
# Length of the intersection: 25
# y_true: 0 y_pred: 1 posterior_c1: 0.588704393896077
#
# RA23
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 93
# Length of the intersection: 50
# y_true: 1 y_pred: 1 posterior_c1: 0.9630000000000001
#
# RA54
# Length of phenotype_associated TCRs:  Fisher: 64 t-test: 83
# Length of the intersection: 46
# y_true: 1 y_pred: 1 posterior_c1: 0.7734418545209908
#
# HC13
# Length of phenotype_associated TCRs:  Fisher: 38 t-test: 99
# Length of the intersection: 31
# y_true: 0 y_pred: 1 posterior_c1: 0.9564807692307693
#
# RA49
# Length of phenotype_associated TCRs:  Fisher: 60 t-test: 77
# Length of the intersection: 42
# y_true: 1 y_pred: 1 posterior_c1: 0.7855977015500091
#
# RA50
# Length of phenotype_associated TCRs:  Fisher: 60 t-test: 84
# Length of the intersection: 44
# y_true: 1 y_pred: 1 posterior_c1: 0.755640360150439
#
# HC19
# Length of phenotype_associated TCRs:  Fisher: 32 t-test: 95
# Length of the intersection: 27
# y_true: 0 y_pred: 1 posterior_c1: 0.970782483645387
#
# RA56
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 88
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.5467755869390895
#
# RA22
# Length of phenotype_associated TCRs:  Fisher: 68 t-test: 89
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.8085523458616136
#
# RA31
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 92
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.7826626353616514
#
# RA81
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 91
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.7400681666213766
#
# RA37
# Length of phenotype_associated TCRs:  Fisher: 68 t-test: 94
# Length of the intersection: 50
# y_true: 1 y_pred: 1 posterior_c1: 0.6364361472732478
#
# RA52
# Length of phenotype_associated TCRs:  Fisher: 60 t-test: 81
# Length of the intersection: 46
# y_true: 1 y_pred: 1 posterior_c1: 0.8955252525252526
#
# RA60
# Length of phenotype_associated TCRs:  Fisher: 63 t-test: 89
# Length of the intersection: 46
# y_true: 1 y_pred: 1 posterior_c1: 0.5284789200559816
#
# RA28
# Length of phenotype_associated TCRs:  Fisher: 70 t-test: 90
# Length of the intersection: 50
# y_true: 1 y_pred: 1 posterior_c1: 0.6752767328868621
#
# RA2
# Length of phenotype_associated TCRs:  Fisher: 70 t-test: 94
# Length of the intersection: 51
# y_true: 1 y_pred: 0 posterior_c1: 0.3755000029093632
#
# RA74
# Length of phenotype_associated TCRs:  Fisher: 66 t-test: 84
# Length of the intersection: 44
# y_true: 1 y_pred: 1 posterior_c1: 0.9171192530003891
#
# RA10
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 93
# Length of the intersection: 50
# y_true: 1 y_pred: 0 posterior_c1: 0.33788767734377134
#
# RA4
# Length of phenotype_associated TCRs:  Fisher: 68 t-test: 88
# Length of the intersection: 46
# y_true: 1 y_pred: 1 posterior_c1: 0.8956071997446997
#
# RA66
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 88
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.7914063152618246
#
# RA62
# Length of phenotype_associated TCRs:  Fisher: 66 t-test: 89
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.714221457895761
#
# RA58
# Length of phenotype_associated TCRs:  Fisher: 68 t-test: 85
# Length of the intersection: 48
# y_true: 1 y_pred: 1 posterior_c1: 0.6707104349709314
#
# HC14
# Length of phenotype_associated TCRs:  Fisher: 32 t-test: 99
# Length of the intersection: 25
# y_true: 0 y_pred: 1 posterior_c1: 0.8980332257003093
#
# HC5
# Length of phenotype_associated TCRs:  Fisher: 30 t-test: 97
# Length of the intersection: 24
# y_true: 0 y_pred: 0 posterior_c1: 0.4122205236410115
#
# RA16
# Length of phenotype_associated TCRs:  Fisher: 69 t-test: 93
# Length of the intersection: 50
# y_true: 1 y_pred: 0 posterior_c1: 0.45215587909719474
#
# HC15
# Length of phenotype_associated TCRs:  Fisher: 31 t-test: 93
# Length of the intersection: 25
# y_true: 0 y_pred: 1 posterior_c1: 0.5766687974546367
#
# HC12
# Length of phenotype_associated TCRs:  Fisher: 36 t-test: 104
# Length of the intersection: 30
# y_true: 0 y_pred: 1 posterior_c1: 0.7893647333190438
#
# RA80
# Length of phenotype_associated TCRs:  Fisher: 61 t-test: 83
# Length of the intersection: 44
# y_true: 1 y_pred: 1 posterior_c1: 0.7608837147988919
#
# RA82
# Length of phenotype_associated TCRs:  Fisher: 67 t-test: 89
# Length of the intersection: 49
# y_true: 1 y_pred: 1 posterior_c1: 0.8234984827146214
#
# RA57

# %% [markdown]
# ### New feature: sum of associated TCRs

# %%
kf = LeaveOneOut()
for train_index,test_index in kf.split(freq_df):
    train_cv, test_cv = freq_df.iloc[train_index], freq_df.iloc[test_index]

    train = train_cv.drop(['sample_name','phenotype_status'],axis=1)
    test = test_cv.drop(['sample_name','phenotype_status'],axis=1)
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.2)
    train['sum_asso_TCRs'] = train[asso_TCRs].sum(axis=1)
    test['sum_asso_TCRs'] = test[asso_TCRs].sum(axis=1)
    
    asso_TCRs = asso_TCRs + ['sum_asso_TCRs']
    
    clf.fit(train[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test[asso_TCRs])[0]
    test_prob = clf.predict_proba(test[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()
    break

# %%
new1 = train_cv.loc[:,asso_TCRs].sum(axis=1)
new2 = train_cv[asso_TCRs].sum(axis=1)
p = pd.DataFrame({'status':train_cv['phenotype_status'],'new_feature':new1})
print(p[p['status']==0]['new_feature'].mean(),p[p['status']==1]['new_feature'].mean())
# Out:
# 5.734544729829541e-05 0.0008260088911752312

# %%
# Init lists
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = freq_df.drop(['sample_name','phenotype_status','total_TCRs'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(freq_df):
    data = freq_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.2)
    
    print('Mean of the sum_asso_TCRs: ','Class 0:',train_cv[train_cv['phenotype_status']==0]['sum_asso_TCRs'].mean(),
          'Class 1:',train_cv[train_cv['phenotype_status']==1]['sum_asso_TCRs'].mean())
    print('Sum_asso_TCRs of the testing sample:',test_cv['sum_asso_TCRs'].tolist()[0])
    
    asso_TCRs = asso_TCRs.tolist()+['sum_asso_TCRs']
    
    clf.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test_cv[asso_TCRs])[0]
    test_prob = clf.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008260088911752312
# Sum_asso_TCRs of the testing sample: 0.00023917723032767282
# y_true: 1 y_pred: 1 posterior_c1: 0.5223180531116328
#
# HC9
# Mean of the sum_asso_TCRs:  Class 0: 4.6174552679196166e-05 Class 1: 0.0004869688251373103
# Sum_asso_TCRs of the testing sample: 0.00033110390040394673
# y_true: 0 y_pred: 1 posterior_c1: 0.9113932257960655
#
# RA29
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0007951761368263883
# Sum_asso_TCRs of the testing sample: 0.00017570832418185812
# y_true: 1 y_pred: 1 posterior_c1: 0.5190735652730691
#
# RA8
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000827469578691439
# Sum_asso_TCRs of the testing sample: 0.00015790304752881732
# y_true: 1 y_pred: 0 posterior_c1: 0.42130515567756677
#
# RA63
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008266545421992621
# Sum_asso_TCRs of the testing sample: 0.00041245617653124357
# y_true: 1 y_pred: 1 posterior_c1: 0.8888784951107376
#
# RA33
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0007909785011165791
# Sum_asso_TCRs of the testing sample: 0.001129305477131564
# y_true: 1 y_pred: 1 posterior_c1: 0.9935483870967741
#
# HC17
# Mean of the sum_asso_TCRs:  Class 0: 5.181706563843592e-05 Class 1: 0.0005169137324436059
# Sum_asso_TCRs of the testing sample: 9.922931895610756e-05
# y_true: 0 y_pred: 0 posterior_c1: 0.43104697008249376
#
# HC3
# Mean of the sum_asso_TCRs:  Class 0: 5.814145618484976e-05 Class 1: 0.0005134920932054964
# Sum_asso_TCRs of the testing sample: 0.00021780165529258023
# y_true: 0 y_pred: 1 posterior_c1: 0.8896091284082155
#
# RA17
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000819734457690524
# Sum_asso_TCRs of the testing sample: 0.0012964563526361278
# y_true: 1 y_pred: 1 posterior_c1: 0.8874269966408929
#
# RA46
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007584114075904552
# Sum_asso_TCRs of the testing sample: 0.00040592652729855896
# y_true: 1 y_pred: 1 posterior_c1: 0.828295027283311
#
# HC6
# Mean of the sum_asso_TCRs:  Class 0: 5.536842674662528e-05 Class 1: 0.0005298338108575353
# Sum_asso_TCRs of the testing sample: 0.0002323285125166986
# y_true: 0 y_pred: 1 posterior_c1: 0.9239550799563268
#
# RA26
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008223741806786938
# Sum_asso_TCRs of the testing sample: 0.0003494365335895868
# y_true: 1 y_pred: 1 posterior_c1: 0.8971981093310168
#
# RA15
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008121865448887744
# Sum_asso_TCRs of the testing sample: 0.0003026451183342413
# y_true: 1 y_pred: 1 posterior_c1: 0.93
#
# RA53
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008001809782521969
# Sum_asso_TCRs of the testing sample: 0.0005232558139534884
# y_true: 1 y_pred: 1 posterior_c1: 0.9690340722495896
#
# RA32
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007823993734903754
# Sum_asso_TCRs of the testing sample: 7.799095304944626e-05
# y_true: 1 y_pred: 0 posterior_c1: 0.3686550988759823
#
# RA40
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008399915882004635
# Sum_asso_TCRs of the testing sample: 0.0
# y_true: 1 y_pred: 0 posterior_c1: 0.1640949573604542
#
# HC8
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.00053884678342703
# Sum_asso_TCRs of the testing sample: 0.0005312084993359894
# y_true: 0 y_pred: 1 posterior_c1: 0.9318153277146635
#
# RA51
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.000806590734124878
# Sum_asso_TCRs of the testing sample: 0.0005675368898978433
# y_true: 1 y_pred: 1 posterior_c1: 0.9546988356471116
#
# RA68
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.000790679242413801
# Sum_asso_TCRs of the testing sample: 0.00021451171770257952
# y_true: 1 y_pred: 1 posterior_c1: 0.6897486541756593
#
# RA21
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007718079671832748
# Sum_asso_TCRs of the testing sample: 0.00025692905546455984
# y_true: 1 y_pred: 1 posterior_c1: 0.5801545269068987
#
# RA13
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008065068605921179
# Sum_asso_TCRs of the testing sample: 0.0005466721333880005
# y_true: 1 y_pred: 1 posterior_c1: 0.8676292963414245
#
# RA3
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008094219389103902
# Sum_asso_TCRs of the testing sample: 0.000525670229542667
# y_true: 1 y_pred: 1 posterior_c1: 0.8783189241617398
#
# RA41
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007947532650992116
# Sum_asso_TCRs of the testing sample: 0.0008603383997705763
# y_true: 1 y_pred: 1 posterior_c1: 0.9706077694235588
#
# RA9
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008084460236043996
# Sum_asso_TCRs of the testing sample: 0.00042038002354128127
# y_true: 1 y_pred: 1 posterior_c1: 0.9216199787608005
#
# RA1
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0008088928390433796
# Sum_asso_TCRs of the testing sample: 0.0005279831045406547
# y_true: 1 y_pred: 1 posterior_c1: 0.9227565385500166
#
# RA5
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008093133104600214
# Sum_asso_TCRs of the testing sample: 0.0003372681281618887
# y_true: 1 y_pred: 1 posterior_c1: 0.8157260543873248
#
# RA48
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007816188547229215
# Sum_asso_TCRs of the testing sample: 0.00021359306249733008
# y_true: 1 y_pred: 1 posterior_c1: 0.7120100563173162
#
# RA6
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008077431942873609
# Sum_asso_TCRs of the testing sample: 0.0005228758169934641
# y_true: 1 y_pred: 1 posterior_c1: 0.8617357929128976
#
# HC1
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.0005160040140798232
# Sum_asso_TCRs of the testing sample: 0.0003742865163282493
# y_true: 0 y_pred: 1 posterior_c1: 0.9373632341723876
#
# RA23
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008118514392207137
# Sum_asso_TCRs of the testing sample: 0.001258917331095258
# y_true: 1 y_pred: 1 posterior_c1: 0.9514117556606313
#
# RA54
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007879661590267829
# Sum_asso_TCRs of the testing sample: 0.0003583515827194903
# y_true: 1 y_pred: 1 posterior_c1: 0.8861681272444245
#
# HC13
# Mean of the sum_asso_TCRs:  Class 0: 6.558722747932256e-05 Class 1: 0.0006157621737643312
# Sum_asso_TCRs of the testing sample: 0.00032789572915812773
# y_true: 0 y_pred: 1 posterior_c1: 0.97875
#
# RA49
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0007577119751584802
# Sum_asso_TCRs of the testing sample: 0.0004244031830238727
# y_true: 1 y_pred: 1 posterior_c1: 0.8901505602240896
#
# RA50
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0007485541664434753
# Sum_asso_TCRs of the testing sample: 0.0002941609060155905
# y_true: 1 y_pred: 1 posterior_c1: 0.8577943836349408
#
# HC19
# Mean of the sum_asso_TCRs:  Class 0: 2.457330830132993e-05 Class 1: 0.0005193225962602614
# Sum_asso_TCRs of the testing sample: 0.0007149666348903719
# y_true: 0 y_pred: 1 posterior_c1: 0.9872685185185185
#
# RA56
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008330021083607618
# Sum_asso_TCRs of the testing sample: 0.00014536292276383372
# y_true: 1 y_pred: 0 posterior_c1: 0.32557986482916734
#
# RA22
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008178668747896059
# Sum_asso_TCRs of the testing sample: 0.0002322071287588529
# y_true: 1 y_pred: 1 posterior_c1: 0.7197446837639478
#
# RA31
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000793850774918109
# Sum_asso_TCRs of the testing sample: 0.000954380606986066
# y_true: 1 y_pred: 1 posterior_c1: 0.8605308733524758
#
# RA81
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0007937630746317337
# Sum_asso_TCRs of the testing sample: 0.0004890453834115806
# y_true: 1 y_pred: 1 posterior_c1: 0.8611456731216661
#
# RA37
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007484653504707328
# Sum_asso_TCRs of the testing sample: 0.0038588754134509374
# y_true: 1 y_pred: 1 posterior_c1: 0.8868330384212736
#
# RA52
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0007341484694501092
# Sum_asso_TCRs of the testing sample: 0.00075937832228016
# y_true: 1 y_pred: 1 posterior_c1: 0.9708095238095238
#
# RA60
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007773728428655968
# Sum_asso_TCRs of the testing sample: 0.0005345211581291759
# y_true: 1 y_pred: 1 posterior_c1: 0.8427535277433857
#
# RA28
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008327432504859127
# Sum_asso_TCRs of the testing sample: 0.00046389361373125093
# y_true: 1 y_pred: 1 posterior_c1: 0.7386373983411696
#
# RA2
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008352781643693926
# Sum_asso_TCRs of the testing sample: 0.00030165912518853697
# y_true: 1 y_pred: 1 posterior_c1: 0.5841519834301219
#
# RA74
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000799027710356233
# Sum_asso_TCRs of the testing sample: 0.0005070351121815185
# y_true: 1 y_pred: 1 posterior_c1: 0.9442213950923627
#
# RA10
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008207537400506283
# Sum_asso_TCRs of the testing sample: 0.0005877167205406994
# y_true: 1 y_pred: 1 posterior_c1: 0.6556597930391639
#
# RA4
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008224534883367061
# Sum_asso_TCRs of the testing sample: 0.00048602673147023093
# y_true: 1 y_pred: 1 posterior_c1: 0.9034730848861284
#
# RA66
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008303780277752017
# Sum_asso_TCRs of the testing sample: 0.0002808199943836001
# y_true: 1 y_pred: 1 posterior_c1: 0.7462148351648352
#
# RA62
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007905148958523695
# Sum_asso_TCRs of the testing sample: 0.000529829394934831
# y_true: 1 y_pred: 1 posterior_c1: 0.8320456256706257
#
# RA58
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000827612979742398
# Sum_asso_TCRs of the testing sample: 0.00021574042112530202
# y_true: 1 y_pred: 0 posterior_c1: 0.42305363815074853
#
# HC14
# Mean of the sum_asso_TCRs:  Class 0: 5.678251837596985e-05 Class 1: 0.0005424698775248689
# Sum_asso_TCRs of the testing sample: 0.00013608219364496155
# y_true: 0 y_pred: 1 posterior_c1: 0.9612419950738916
#
# HC5
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.00047320344199084535
# Sum_asso_TCRs of the testing sample: 0.0
# y_true: 0 y_pred: 0 posterior_c1: 0.23409049895244313
#
# RA16
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008056813921461641
# Sum_asso_TCRs of the testing sample: 0.0010292301358583778
# y_true: 1 y_pred: 1 posterior_c1: 0.8446685335750928
#
# HC15
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.0004820436364392983
# Sum_asso_TCRs of the testing sample: 0.00011301989150090416
# y_true: 0 y_pred: 1 posterior_c1: 0.6505756126499397
#
# HC12
# Mean of the sum_asso_TCRs:  Class 0: 5.855970412003234e-05 Class 1: 0.0005794239005613909
# Sum_asso_TCRs of the testing sample: 0.0003386769022352676
# y_true: 0 y_pred: 1 posterior_c1: 0.9471856139030053
#
# RA80
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007599523397415923
# Sum_asso_TCRs of the testing sample: 0.0004170914820650662
# y_true: 1 y_pred: 1 posterior_c1: 0.8677814234822346
#
# RA82
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.0008109554623164601
# Sum_asso_TCRs of the testing sample: 0.00028052064631956913
# y_true: 1 y_pred: 1 posterior_c1: 0.8057800911618749
#
# RA57
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007948012944691626
# Sum_asso_TCRs of the testing sample: 0.0002720940356987375
# y_true: 1 y_pred: 1 posterior_c1: 0.7636703108863111
#
# RA72
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007937685564738963
# Sum_asso_TCRs of the testing sample: 0.0002914602156805596
# y_true: 1 y_pred: 1 posterior_c1: 0.6094469103992345
#
# RA18
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008303465264720686
# Sum_asso_TCRs of the testing sample: 0.0006172839506172839
# y_true: 1 y_pred: 1 posterior_c1: 0.8255330569065777
#
# HC20
# Mean of the sum_asso_TCRs:  Class 0: 4.2258619970055376e-05 Class 1: 0.0005160459365288736
# Sum_asso_TCRs of the testing sample: 0.0004247286455875413
# y_true: 0 y_pred: 1 posterior_c1: 0.98
#
# RA14
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008230217266745335
# Sum_asso_TCRs of the testing sample: 0.0010860711376595167
# y_true: 1 y_pred: 1 posterior_c1: 0.7424726600397525
#
# RA7
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008399915882004635
# Sum_asso_TCRs of the testing sample: 0.0
# y_true: 1 y_pred: 0 posterior_c1: 0.17249461061716967
#
# RA79
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007867841934741513
# Sum_asso_TCRs of the testing sample: 0.00033932813030200206
# y_true: 1 y_pred: 1 posterior_c1: 0.7466927961023151
#
# RA25
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007993588623547995
# Sum_asso_TCRs of the testing sample: 0.00029220237101352484
# y_true: 1 y_pred: 1 posterior_c1: 0.6787382064795107
#
# HC18
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.0005390897495751439
# Sum_asso_TCRs of the testing sample: 0.0004977954771725216
# y_true: 0 y_pred: 1 posterior_c1: 0.9135071614943736
#
# RA59
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007946061679361986
# Sum_asso_TCRs of the testing sample: 0.0003564808213318123
# y_true: 1 y_pred: 1 posterior_c1: 0.9148846241199182
#
# RA70
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000817070659930664
# Sum_asso_TCRs of the testing sample: 0.00033515808289576583
# y_true: 1 y_pred: 1 posterior_c1: 0.7312522495877076
#
# HC7
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.00048053394471122136
# Sum_asso_TCRs of the testing sample: 4.925380485642516e-05
# y_true: 0 y_pred: 0 posterior_c1: 0.1893206480824259
#
# RA69
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008399915882004635
# Sum_asso_TCRs of the testing sample: 0.0
# y_true: 1 y_pred: 0 posterior_c1: 0.184094193595095
#
# HC10
# Mean of the sum_asso_TCRs:  Class 0: 5.5200604255086316e-05 Class 1: 0.0005397203523570181
# Sum_asso_TCRs of the testing sample: 0.0003676245328104896
# y_true: 0 y_pred: 1 posterior_c1: 0.9431999999999999
#
# RA12
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.000810785980723828
# Sum_asso_TCRs of the testing sample: 0.0018691588785046728
# y_true: 1 y_pred: 1 posterior_c1: 0.904653422487474
#
# RA11
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008276735492888715
# Sum_asso_TCRs of the testing sample: 0.00025075225677031093
# y_true: 1 y_pred: 1 posterior_c1: 0.6537960226303912
#
# HC4
# Mean of the sum_asso_TCRs:  Class 0: 5.348093856577421e-05 Class 1: 0.0005267498679595732
# Sum_asso_TCRs of the testing sample: 0.000242160067804819
# y_true: 0 y_pred: 1 posterior_c1: 0.9407506345506345
#
# RA19
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008284895842251512
# Sum_asso_TCRs of the testing sample: 0.00018953752843062926
# y_true: 1 y_pred: 1 posterior_c1: 0.5712214387314111
#
# RA30
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008165681841632537
# Sum_asso_TCRs of the testing sample: 0.00029886431560071725
# y_true: 1 y_pred: 1 posterior_c1: 0.7682212260245437
#
# RA24
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007682614726145602
# Sum_asso_TCRs of the testing sample: 0.0003518648838845883
# y_true: 1 y_pred: 1 posterior_c1: 0.8446813383690709
#
# HC11
# Mean of the sum_asso_TCRs:  Class 0: 6.350246390886674e-05 Class 1: 0.0006368375386554414
# Sum_asso_TCRs of the testing sample: 0.0003244646333549643
# y_true: 0 y_pred: 1 posterior_c1: 0.8931411231884057
#
# RA55
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007474041033889506
# Sum_asso_TCRs of the testing sample: 0.00033378765541987706
# y_true: 1 y_pred: 1 posterior_c1: 0.8941448296879144
#
# RA20
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008315250479674643
# Sum_asso_TCRs of the testing sample: 0.000541858574911948
# y_true: 1 y_pred: 1 posterior_c1: 0.8887157319608593
#
# HC2
# Mean of the sum_asso_TCRs:  Class 0: 6.06545220006922e-05 Class 1: 0.0005769031351501941
# Sum_asso_TCRs of the testing sample: 0.00033536789858474745
# y_true: 0 y_pred: 1 posterior_c1: 0.994079254079254
#
# RA65
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0008042342128106347
# Sum_asso_TCRs of the testing sample: 0.0005718097779472029
# y_true: 1 y_pred: 1 posterior_c1: 0.9281859416389335
#
# RA75
# Mean of the sum_asso_TCRs:  Class 0: 5.4034408294255926e-05 Class 1: 0.000740373247829268
# Sum_asso_TCRs of the testing sample: 0.0007725653461521954
# y_true: 1 y_pred: 1 posterior_c1: 0.9827777777777778
#
# RA76
# Mean of the sum_asso_TCRs:  Class 0: 5.734544729829541e-05 Class 1: 0.0007644859877473392
# Sum_asso_TCRs of the testing sample: 0.00017164435290078955
# y_true: 1 y_pred: 1 posterior_c1: 0.5041907178341143
#
# HC16
# Mean of the sum_asso_TCRs:  Class 0: 4.965985689397455e-05 Class 1: 0.00047320344199084535
# Sum_asso_TCRs of the testing sample: 0.0
# y_true: 0 y_pred: 0 posterior_c1: 0.25761885721095973
#
# cv auroc: 0.31923076923076926
# cv log_loss: 0.8319942585546145

# %%
# Init lists
sample_name = []
y_true = []
y_pred = []
y_proba = [] 

TCRs = freq_df.drop(['sample_name','phenotype_status','total_TCRs'],axis=1).columns.values

kf = LeaveOneOut()
for train_index,test_index in kf.split(freq_df):
    data = freq_df.copy(deep=True)
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]
    print(test_cv['sample_name'].tolist()[0])
    
    asso_TCRs = TCRs_selection(train_cv,TCRs,0.2)
    train_cv['sum_asso_TCRs'] = train_cv[asso_TCRs].sum(axis=1)
    test_cv['sum_asso_TCRs'] = test_cv[asso_TCRs].sum(axis=1)
    
    clf.fit(train_cv[asso_TCRs],train_cv['phenotype_status'])
    test_pred = clf.predict(test_cv[asso_TCRs])[0]
    test_prob = clf.predict_proba(test_cv[asso_TCRs])[:,1][0]

    sample_name.append(test_cv['sample_name'].tolist()[0])
    y_true.append(test_cv['phenotype_status'].values[0])
    y_pred.append(test_pred)
    y_proba.append(test_prob)

    
    print('y_true:',test_cv['phenotype_status'].values[0],'y_pred:',test_pred,'posterior_c1:',test_prob)
    print()

print('cv auroc:',roc_auc_score(y_true,y_proba))
print('cv log_loss:',log_loss(y_true,y_proba))
# Out:
# RA47
# y_true: 1 y_pred: 0 posterior_c1: 0.4559243242160052
#
# HC9
# y_true: 0 y_pred: 1 posterior_c1: 0.5476924953305642
#
# RA29
# y_true: 1 y_pred: 0 posterior_c1: 0.45157156172347307
#
# RA8
# y_true: 1 y_pred: 0 posterior_c1: 0.4344244698052342
#
# RA63
# y_true: 1 y_pred: 1 posterior_c1: 0.7158866604858796
#
# RA33
# y_true: 1 y_pred: 1 posterior_c1: 0.9745454545454545
#
# HC17
# y_true: 0 y_pred: 0 posterior_c1: 0.4862684078541365
#
# HC3
# y_true: 0 y_pred: 1 posterior_c1: 0.6173276693652499
#
# RA17
# y_true: 1 y_pred: 1 posterior_c1: 0.5887854115192951
#
# RA46
# y_true: 1 y_pred: 1 posterior_c1: 0.7277714377437766
#
# HC6
# y_true: 0 y_pred: 1 posterior_c1: 0.7040144856241488
#
# RA26
# y_true: 1 y_pred: 1 posterior_c1: 0.7026920565878476
#
# RA15
# y_true: 1 y_pred: 1 posterior_c1: 0.8094983948887419
#
# RA53
# y_true: 1 y_pred: 1 posterior_c1: 0.8304122810200124
#
# RA32
# y_true: 1 y_pred: 1 posterior_c1: 0.5818559949210795
#
# RA40
# y_true: 1 y_pred: 0 posterior_c1: 0.2642936404254288
#
# HC8
# y_true: 0 y_pred: 1 posterior_c1: 0.758694520026563
#
# RA51
# y_true: 1 y_pred: 1 posterior_c1: 0.9213630952380953
#
# RA68
# y_true: 1 y_pred: 1 posterior_c1: 0.7594342077037882
#
# RA21
# y_true: 1 y_pred: 1 posterior_c1: 0.5813621151028986
#
# RA13
# y_true: 1 y_pred: 1 posterior_c1: 0.6775196763509069
#
# RA3
# y_true: 1 y_pred: 1 posterior_c1: 0.7251433690636513
#
# RA41
# y_true: 1 y_pred: 1 posterior_c1: 0.9412745341614905
#
# RA9
# y_true: 1 y_pred: 1 posterior_c1: 0.7538133591563531
#
# RA1
# y_true: 1 y_pred: 1 posterior_c1: 0.7889378240784114
#
# RA5
# y_true: 1 y_pred: 0 posterior_c1: 0.4574244664917542
#
# RA48
# y_true: 1 y_pred: 1 posterior_c1: 0.6813165934744236
#
# RA6
# y_true: 1 y_pred: 1 posterior_c1: 0.6981147545930788
#
# HC1
# y_true: 0 y_pred: 1 posterior_c1: 0.6497458147442923
#
# RA23
# y_true: 1 y_pred: 1 posterior_c1: 0.8471363782467937
#
# RA54
# y_true: 1 y_pred: 1 posterior_c1: 0.7468683130333903
#
# HC13
# y_true: 0 y_pred: 1 posterior_c1: 0.8756479138677414
#
# RA49
# y_true: 1 y_pred: 1 posterior_c1: 0.7889625754082142
#
# RA50
# y_true: 1 y_pred: 1 posterior_c1: 0.7253033569137574
#
# HC19
# y_true: 0 y_pred: 1 posterior_c1: 0.9137532192852282
#
# RA56
# y_true: 1 y_pred: 0 posterior_c1: 0.44851566713618385
#
# RA22
# y_true: 1 y_pred: 1 posterior_c1: 0.7377597667037741
#
# RA31
# y_true: 1 y_pred: 1 posterior_c1: 0.6816816025950458
#
# RA81
# y_true: 1 y_pred: 1 posterior_c1: 0.7185023108810864
#
# RA37
# y_true: 1 y_pred: 1 posterior_c1: 0.8020964855227787
#
# RA52
# y_true: 1 y_pred: 1 posterior_c1: 0.9232589587559161
#
# RA60
# y_true: 1 y_pred: 1 posterior_c1: 0.6557273131627263
#
# RA28
# y_true: 1 y_pred: 1 posterior_c1: 0.5206563209719476
#
# RA2
# y_true: 1 y_pred: 0 posterior_c1: 0.32171334759657194
#
# RA74
# y_true: 1 y_pred: 1 posterior_c1: 0.9097391480730224
#
# RA10
# y_true: 1 y_pred: 0 posterior_c1: 0.41635126294449504
#
# RA4
# y_true: 1 y_pred: 1 posterior_c1: 0.8300633331073888
#
# RA66
# y_true: 1 y_pred: 1 posterior_c1: 0.8026229679405702
#
# RA62
# y_true: 1 y_pred: 1 posterior_c1: 0.6394546893786593
#
# RA58
# y_true: 1 y_pred: 0 posterior_c1: 0.49612725019627163
#
# HC14
# y_true: 0 y_pred: 1 posterior_c1: 0.7911726695291048
#
# HC5
# y_true: 0 y_pred: 0 posterior_c1: 0.341548053117102
#
# RA16
# y_true: 1 y_pred: 1 posterior_c1: 0.6959114479732681
#
# HC15
# y_true: 0 y_pred: 0 posterior_c1: 0.48137828205869293
#
# HC12
# y_true: 0 y_pred: 1 posterior_c1: 0.7381176811039477
#
# RA80
# y_true: 1 y_pred: 1 posterior_c1: 0.7804073193537916
#
# RA82
# y_true: 1 y_pred: 1 posterior_c1: 0.8074049121296784
#
# RA57
# y_true: 1 y_pred: 1 posterior_c1: 0.6787341487591376
#
# RA72
# y_true: 1 y_pred: 1 posterior_c1: 0.5142945785873223
#
# RA18
# y_true: 1 y_pred: 1 posterior_c1: 0.597050278234447
#
# HC20
# y_true: 0 y_pred: 1 posterior_c1: 0.9792592592592593
#
# RA14
# y_true: 1 y_pred: 0 posterior_c1: 0.4512012226575681
#
# RA7
# y_true: 1 y_pred: 0 posterior_c1: 0.27747270340014313
#
# RA79
# y_true: 1 y_pred: 0 posterior_c1: 0.3493898406662313
#
# RA25
# y_true: 1 y_pred: 1 posterior_c1: 0.5882444154436008
#
# HC18
# y_true: 0 y_pred: 1 posterior_c1: 0.7776728226673937
#
# RA59
# y_true: 1 y_pred: 1 posterior_c1: 0.6759364859252485
#
# RA70
# y_true: 1 y_pred: 1 posterior_c1: 0.6242433619430038
#
# HC7
# y_true: 0 y_pred: 0 posterior_c1: 0.4845052329351698
#
# RA69
# y_true: 1 y_pred: 0 posterior_c1: 0.2908225192785372
#
# HC10
# y_true: 0 y_pred: 1 posterior_c1: 0.8121712139278415
#
# RA12
# y_true: 1 y_pred: 1 posterior_c1: 0.8730171930841302
#
# RA11
# y_true: 1 y_pred: 1 posterior_c1: 0.6099105403349147
#
# HC4
# y_true: 0 y_pred: 1 posterior_c1: 0.7727022818871222
#
# RA19
# y_true: 1 y_pred: 1 posterior_c1: 0.6645896541531817
#
# RA30
# y_true: 1 y_pred: 0 posterior_c1: 0.4880884416965207
#
# RA24
# y_true: 1 y_pred: 1 posterior_c1: 0.6290970179638312
#
# HC11
# y_true: 0 y_pred: 1 posterior_c1: 0.7334380499388999
#
# RA55
# y_true: 1 y_pred: 1 posterior_c1: 0.7616548282965365
#
# RA20
# y_true: 1 y_pred: 1 posterior_c1: 0.7210867617791292
#
# HC2
# y_true: 0 y_pred: 1 posterior_c1: 0.7729648957275812
#
# RA65
# y_true: 1 y_pred: 1 posterior_c1: 0.7429386021940286
#
# RA75
# y_true: 1 y_pred: 1 posterior_c1: 0.8825121226980496
#
# RA76
# y_true: 1 y_pred: 1 posterior_c1: 0.5583606072241537
#
# HC16
# y_true: 0 y_pred: 0 posterior_c1: 0.35311573134082863
#
# cv auroc: 0.4523076923076923
# cv log_loss: 0.6689838776906415
