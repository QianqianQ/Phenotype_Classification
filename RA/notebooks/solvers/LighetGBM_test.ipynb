# %%
# Handle table-like data and matrices
import numpy as np
import pandas as pd

# Helpers
from helpers import *
import sys
import pickle

# model selection
from sklearn.model_selection import LeaveOneOut,KFold,StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,roc_auc_score,log_loss
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Algorithm
from MAP_estimator import MAP_estimator
import lightgbm as lgb

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
def fit_evaluate_model_lgbm(X_train, Y_train, X_valid, Y_valid, train_data_columns, importance=False):
    
    X_trainDF = pd.DataFrame(X_train, columns=train_data_columns)
    X_validDF = pd.DataFrame(X_valid, columns=train_data_columns)
    train_dataset = lgb.Dataset(X_trainDF, Y_train.reshape(Y_train.shape[0]))
    test_dataset = lgb.Dataset(X_validDF, Y_valid.reshape(Y_valid.shape[0]))
    
    # Fit
    params = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'boosting': 'gbdt'
    }
    gbm = lgb.train(params, train_dataset)
    # Evaluate
    predict_y_proba_gbm = gbm.predict(X_valid, num_iteration=gbm.best_iteration) # Proba of class 1
    predict_y_gbm = np.where(predict_y_proba_gbm.reshape((predict_y_proba_gbm.shape[0])) > 0.5, 1, 0)

    
    if (importance == True):
        ax = lgb.plot_importance(gbm, max_num_features=20, figsize=(16, 5))
        plt.show()
    
    # gbmDF = pd.DataFrame([tuple(gbm.feature_importance())], columns= gbm.feature_name())
    # gbmDF.sort_index(axis=1, inplace=True)
    gbmDF = pd.DataFrame({'TCR': gbm.feature_name(),'Feature_Importance':gbm.feature_imporatance()})
    
    return score, gbmDF, gbm

# %%
clf = lgb.LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
                        learning_rate=0.1, max_depth=-1, min_child_samples=20,
                        min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
                        n_jobs=-1, num_leaves=31, objective='binary', random_state=0,
                        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
                        subsample_for_bin=200000, subsample_freq=1)
LOO = LeaveOneOut()
version = ['count','bin','freq']

# %%
for v in version:
    print('Version:',v)
    data = pd.read_pickle('../data/' + v + '_df.pkl')
    LOO_CV(clf,data,v,verbose=False)
# Out:
# Version: count
# loocv auroc: 0.6569230769230768
# loocv accuracy: 0.6941176470588235
#
# Version: bin
# loocv auroc: 0.6715384615384616
# loocv accuracy: 0.6941176470588235
#
# Version: freq
# loocv auroc: 0.6561538461538462
# loocv accuracy: 0.6941176470588235

# %%
for v in version:
    print('Version:',v)
    data = pd.read_pickle('../data/' + v + '_df.pkl')
    if v == 'freq':
        drop_cols = ['sample_name', 'phenotype_status','total_TCRs']
    else:
        drop_cols = ['sample_name', 'phenotype_status']
    X = data.drop(drop_cols, axis=1).values
    y = data['phenotype_status']
    print('The number of correctly classified samples:',
          np.count_nonzero(cross_val_score(clf,X,y,cv=LOO,scoring='accuracy')))
# Out:
# Version: count
# The number of correctly classified samples: 59
# Version: bin
# The number of correctly classified samples: 59
# Version: freq
# The number of correctly classified samples: 59

# %%
version = ['bin']
for v in version:
    print('Version:',v)
    data = pd.read_pickle('../data/' + v + '_df.pkl')
    LOO_CV(clf,data,v,verbose=True)
# Out:
# Version: bin
# RA47
# y_true: 1 y_pred: 1 posterior_c1: 0.599
#
# HC9
# y_true: 0 y_pred: 1 posterior_c1: 0.716
#
# RA29
# y_true: 1 y_pred: 1 posterior_c1: 0.929
#
# RA8
# y_true: 1 y_pred: 1 posterior_c1: 0.987
#
# RA63
# y_true: 1 y_pred: 1 posterior_c1: 0.977
#
# RA33
# y_true: 1 y_pred: 1 posterior_c1: 0.988
#
# HC17
# y_true: 0 y_pred: 0 posterior_c1: 0.426
#
# HC3
# y_true: 0 y_pred: 1 posterior_c1: 0.895
#
# RA17
# y_true: 1 y_pred: 1 posterior_c1: 0.935
#
# RA46
# y_true: 1 y_pred: 0 posterior_c1: 0.432
#
# HC6
# y_true: 0 y_pred: 0 posterior_c1: 0.289
#
# RA26
# y_true: 1 y_pred: 0 posterior_c1: 0.442
#
# RA15
# y_true: 1 y_pred: 1 posterior_c1: 0.941
#
# RA53
# y_true: 1 y_pred: 1 posterior_c1: 0.843
#
# RA32
# y_true: 1 y_pred: 0 posterior_c1: 0.373
#
# RA40
# y_true: 1 y_pred: 1 posterior_c1: 0.687
#
# HC8
# y_true: 0 y_pred: 1 posterior_c1: 0.936
#
# RA51
# y_true: 1 y_pred: 1 posterior_c1: 0.631
#
# RA68
# y_true: 1 y_pred: 1 posterior_c1: 0.904
#
# RA21
# y_true: 1 y_pred: 1 posterior_c1: 0.942
#
# RA13
# y_true: 1 y_pred: 1 posterior_c1: 0.887
#
# RA3
# y_true: 1 y_pred: 1 posterior_c1: 0.9
#
# RA41
# y_true: 1 y_pred: 1 posterior_c1: 0.983
#
# RA9
# y_true: 1 y_pred: 1 posterior_c1: 0.978
#
# RA1
# y_true: 1 y_pred: 1 posterior_c1: 0.868
#
# RA5
# y_true: 1 y_pred: 1 posterior_c1: 0.57
#
# RA48
# y_true: 1 y_pred: 1 posterior_c1: 0.8
#
# RA6
# y_true: 1 y_pred: 1 posterior_c1: 0.973
#
# HC1
# y_true: 0 y_pred: 1 posterior_c1: 0.566
#
# RA23
# y_true: 1 y_pred: 1 posterior_c1: 0.983
#
# RA54
# y_true: 1 y_pred: 1 posterior_c1: 0.825
#
# HC13
# y_true: 0 y_pred: 0 posterior_c1: 0.483
#
# RA49
# y_true: 1 y_pred: 1 posterior_c1: 0.757
#
# RA50
# y_true: 1 y_pred: 1 posterior_c1: 0.939
#
# HC19
# y_true: 0 y_pred: 1 posterior_c1: 0.828
#
# RA56
# y_true: 1 y_pred: 1 posterior_c1: 0.738
#
# RA22
# y_true: 1 y_pred: 1 posterior_c1: 0.785
#
# RA31
# y_true: 1 y_pred: 1 posterior_c1: 0.923
#
# RA81
# y_true: 1 y_pred: 1 posterior_c1: 0.765
#
# RA37
# y_true: 1 y_pred: 1 posterior_c1: 0.987
#
# RA52
# y_true: 1 y_pred: 1 posterior_c1: 0.951
#
# RA60
# y_true: 1 y_pred: 1 posterior_c1: 0.888
#
# RA28
# y_true: 1 y_pred: 1 posterior_c1: 0.638
#
# RA2
# y_true: 1 y_pred: 1 posterior_c1: 0.906
#
# RA74
# y_true: 1 y_pred: 1 posterior_c1: 0.963
#
# RA10
# y_true: 1 y_pred: 1 posterior_c1: 0.887
#
# RA4
# y_true: 1 y_pred: 1 posterior_c1: 0.952
#
# RA66
# y_true: 1 y_pred: 1 posterior_c1: 0.782
#
# RA62
# y_true: 1 y_pred: 1 posterior_c1: 0.915
#
# RA58
# y_true: 1 y_pred: 1 posterior_c1: 0.901
#
# HC14
# y_true: 0 y_pred: 1 posterior_c1: 0.901
#
# HC5
# y_true: 0 y_pred: 1 posterior_c1: 0.852
#
# RA16
# y_true: 1 y_pred: 1 posterior_c1: 0.923
#
# HC15
# y_true: 0 y_pred: 1 posterior_c1: 0.52
#
# HC12
# y_true: 0 y_pred: 1 posterior_c1: 0.631
#
# RA80
# y_true: 1 y_pred: 0 posterior_c1: 0.302
#
# RA82
# y_true: 1 y_pred: 1 posterior_c1: 0.899
#
# RA57
# y_true: 1 y_pred: 1 posterior_c1: 0.936
#
# RA72
# y_true: 1 y_pred: 1 posterior_c1: 0.651
#
# RA18
# y_true: 1 y_pred: 1 posterior_c1: 0.942
#
# HC20
# y_true: 0 y_pred: 0 posterior_c1: 0.469
#
# RA14
# y_true: 1 y_pred: 1 posterior_c1: 0.887
#
# RA7
# y_true: 1 y_pred: 1 posterior_c1: 0.901
#
# RA79
# y_true: 1 y_pred: 0 posterior_c1: 0.47
#
# RA25
# y_true: 1 y_pred: 0 posterior_c1: 0.318
#
# HC18
# y_true: 0 y_pred: 1 posterior_c1: 0.84
#
# RA59
# y_true: 1 y_pred: 1 posterior_c1: 0.955
#
# RA70
# y_true: 1 y_pred: 1 posterior_c1: 0.935
#
# HC7
# y_true: 0 y_pred: 1 posterior_c1: 0.942
#
# RA69
# y_true: 1 y_pred: 1 posterior_c1: 0.975
#
# HC10
# y_true: 0 y_pred: 1 posterior_c1: 0.9
#
# RA12
# y_true: 1 y_pred: 1 posterior_c1: 0.896
#
# RA11
# y_true: 1 y_pred: 0 posterior_c1: 0.241
#
# HC4
# y_true: 0 y_pred: 1 posterior_c1: 0.822
#
# RA19
# y_true: 1 y_pred: 1 posterior_c1: 0.938
#
# RA30
# y_true: 1 y_pred: 1 posterior_c1: 0.927
#
# RA24
# y_true: 1 y_pred: 0 posterior_c1: 0.359
#
# HC11
# y_true: 0 y_pred: 1 posterior_c1: 0.778
#
# RA55
# y_true: 1 y_pred: 1 posterior_c1: 0.87
#
# RA20
# y_true: 1 y_pred: 1 posterior_c1: 0.886
#
# HC2
# y_true: 0 y_pred: 1 posterior_c1: 0.644
#
# RA65
# y_true: 1 y_pred: 0 posterior_c1: 0.381
#
# RA75
# y_true: 1 y_pred: 0 posterior_c1: 0.212
#
# RA76
# y_true: 1 y_pred: 1 posterior_c1: 0.554
#
# HC16
# y_true: 0 y_pred: 1 posterior_c1: 0.655
#
# loocv auroc: 0.6715384615384616
# loocv accuracy: 0.6941176470588235

# %% [markdown]
# ## Feature Selection

# %%
data = pd.read_pickle('../data/' + 'count' + '_df.pkl')

# %%
drop_cols = ['sample_name', 'phenotype_status']
kf = LeaveOneOut()
for train_index, test_index in kf.split(data):
    train_cv, test_cv = data.iloc[train_index], data.iloc[test_index]

    X_train = train_cv.drop(drop_cols, axis=1)
    X_test = test_cv.drop(drop_cols, axis=1)
    break

# %%
clf.fit(X_train, train_cv['phenotype_status'])
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         learning_rate=0.1, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#         n_jobs=-1, num_leaves=31, objective='binary', random_state=0,
#         reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
#         subsample_for_bin=200000, subsample_freq=1)

# %%
np.where(clf.feature_importances_!=0)
# Out:
# (array([ 2438,  2631,  2641,  3508,  5683,  7250, 10086, 11026, 11116,
#         11568, 11695, 13452, 13467, 26767, 26880, 33858]),)

# %%
X_train2 = lgb.Dataset(X_train,train_cv['phenotype_status'])
X_test2 = lgb.Dataset(X_test,test_cv['phenotype_status'])

# %%
params = {
            'objective': 'binary',
            'metric': 'binary_logloss',
            'boosting': 'gbdt'
        }

# %%
gbm = lgb.train(params,X_train2)

# %%
gbm.feature_importance_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
gbmDF = pd.DataFrame({'TCR': gbm.feature_name(),'Feature_Importance':gbm.feature_importance})

# %%
np.where(gbm.feature_importance()!=0)
# Out:
# (array([ 2438,  2631,  2641,  3508,  5683,  7250, 10086, 11026, 11116,
#         11568, 11695, 13452, 13467, 26767, 26880, 33858]),)

# %%
gbm.predict(X_test.values,num_iteration=gbm.best_iteration)
# Out:
# array([0.59556484])

# %%
gbmDF.sort_index(axis=1, inplace=True)

# %%
gbmDF.T.sort_values()
# Out:
#                                                     0
# ('CAAGGSSYEQYF',_'TCRBV07',_'TCRBV07-08',_'01',...  0
# ('CACLPGQTSYEQYF',_'TCRBV30',_'TCRBV30-01',_'01...  0
# ('CACRGEGGNTIYF',_'TCRBV30',_'TCRBV30-01',_'01'...  0
# ('CAFGQEGQPQHF',_'TCRBV30',_'TCRBV30-01',_'01',...  0
# ('CAGETAEAFF',_'TCRBV06',_'TCRBV06-01',_'01',_'...  0
# ('CAGGMNTEAFF',_'TCRBV30',_'TCRBV30-01',_'01',_...  0
# ('CAGGNTEAFF',_'TCRBV02',_'TCRBV02-01',_'01',_'...  0
# ('CAGGRAGGTDTQYF',_'TCRBV07',_'TCRBV07-09',_'nu...  0
# ('CAGGTEAFF',_'TCRBV06',_'TCRBV06-01',_'01',_'T...  0
# ('CAGGTGDSNQPQHF',_'TCRBV10',_'TCRBV10-03',_'01...  0
# ('CAIAGKGGYGYTF',_'TCRBV11',_'TCRBV11-02',_'02'...  0
# ('CAIDRNTGELFF',_'TCRBV02',_'TCRBV02-01',_'01',...  0
# ('CAIGGDSYEQYF',_'TCRBV10',_'TCRBV10-03',_'01',...  0
# ('CAIGQPQHF',_'TCRBV10',_'TCRBV10-03',_'01',_'T...  0
# ('CAIGTGDSNQPQHF',_'TCRBV10',_'TCRBV10-03',_'01...  0
# ('CAIGTGGNTGELFF',_'TCRBV10',_'TCRBV10-03',_'01...  0
# ('CAIGTGGSYEQYF',_'TCRBV10',_'TCRBV10-03',_'01'...  0
# ('CAIGTGNTEAFF',_'TCRBV10',_'TCRBV10-03',_'01',...  0
